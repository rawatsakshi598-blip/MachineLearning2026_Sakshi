# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
diamonds_df=pd.read_csv(r'C:\Users\acer\Desktop\diamonds.csv')

# %%
diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_df=sns.load_dataset('diamonds')

# %%
diamonds_df=diamonds_df[(diamonds_df["clarity"]=="SI2")&(diamonds_df["color"]=="E")]

# %%
plt.figure(figsize=(8.5,5))
plt.scatter(diamonds_df["carat"],diamonds_df["price"])

# %%
c=diamonds_df["cut"].astype("category").cat.codes
cmap="viridis"
alpha=0.7

# %%
plt.title("carat vs price(colorE.clarity SI2)")
plt.xlabel("carat")
plt.ylabel("price")
plt.colorbar(label="cut")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 4
#       2 plt.xlabel("carat")
#       3 plt.ylabel("price")
# ----> 4 plt.colorbar(label="cut")
#       5 plt.tight_layout()
#       6 plt.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\pyplot.py:2529, in colorbar(mappable, cax, ax, **kwargs)
#    2527     mappable = gci()
#    2528     if mappable is None:
# -> 2529         raise RuntimeError('No mappable was found to use for colorbar '
#    2530                            'creation. First define a mappable such as '
#    2531                            'an image (with imshow) or a contour set ('
#    2532                            'with contourf).')
#    2533 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2534 return ret
#
# ...
