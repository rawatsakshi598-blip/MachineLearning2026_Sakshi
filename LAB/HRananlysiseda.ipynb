# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\acer\Desktop\HR-Employee-Attrition.csv')

# %%
df[['Age','MonthlyIncome','JobSatisfaction','YearsAtCompany','OverTime',
    'Department','JobRole','WorkLifeBalance','EnvironmentSatisfaction',
    'TotalWorkingYears','YearsSinceLastPromotion','Attrition']].info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   MonthlyIncome            1470 non-null   int64
#  2   JobSatisfaction          1470 non-null   int64
#  3   YearsAtCompany           1470 non-null   int64
#  4   OverTime                 1470 non-null   str
#  5   Department               1470 non-null   str
#  6   JobRole                  1470 non-null   str
#  7   WorkLifeBalance          1470 non-null   int64
#  8   EnvironmentSatisfaction  1470 non-null   int64
#  9   TotalWorkingYears        1470 non-null   int64
#  10  YearsSinceLastPromotion  1470 non-null   int64
#  11  Attrition                1470 non-null   str
# dtypes: int64(8), str(4)
# memory usage: 137.9 KB
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
num_cols = ['Age','MonthlyIncome','YearsAtCompany',
            'TotalWorkingYears','YearsSinceLastPromotion']

# %%
df[num_cols].hist(figsize=(12,8))
plt.show()

# %%
df[num_cols].boxplot(figsize=(12,6))
plt.show()

# %%
cat_cols = ['OverTime','Department','JobRole',
            'JobSatisfaction','WorkLifeBalance',
            'EnvironmentSatisfaction','Attrition']

# %%
for col in cat_cols:
    print(df[col].value_counts())
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
for col in cat_cols:
    sns.countplot(x=col, data=df)
    plt.title(col)
    plt.show()

# %%
sns.boxplot(x='Attrition', y='Age', data=df)
plt.show()

# %%
sns.boxplot(x='Attrition', y='MonthlyIncome', data=df)
plt.show()

# %%
sns.countplot(x='OverTime', hue='Attrition', data=df)
plt.show()

# %%
sns.countplot(x='JobSatisfaction', hue='Attrition', data=df)
plt.show()

# %%
sns.countplot(x='Department', hue='Attrition', data=df)
plt.show()

# %%
corr = df[num_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
