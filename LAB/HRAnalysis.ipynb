# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Employee_df=pd.read_csv(r'C:\Users\acer\Desktop\HR-Employee-Attrition.csv')

# %%
Employee_df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
Employee_df['Attrition']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: str

# %%
Employee_df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
Employee_df['Attrition'].value_counts(normalize=True)
# Out:
# Attrition
# No     0.838776
# Yes    0.161224
# Name: proportion, dtype: float64

# %%
Employee_df['EmployeeCount']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: EmployeeCount, Length: 1470, dtype: int64

# %%
Employee_df['EmployeeCount'].unique()
# Out:
# array([1])

# %%
Employee_df['Attrition'].unique()
# Out:
# <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
Employee_df_bi=Employee_df[['Age','Gender','MaritalStatus','BusinessTravel','Attrition']]
Employee_df_bi
# Out:
#       Age  Gender MaritalStatus     BusinessTravel Attrition
# 0      41  Female        Single      Travel_Rarely       Yes
# 1      49    Male       Married  Travel_Frequently        No
# 2      37    Male        Single      Travel_Rarely       Yes
# 3      33  Female       Married  Travel_Frequently        No
# 4      27    Male       Married      Travel_Rarely        No
# ...   ...     ...           ...                ...       ...
# 1465   36    Male       Married  Travel_Frequently        No
# 1466   39    Male       Married      Travel_Rarely        No
# 1467   27    Male       Married      Travel_Rarely        No
# 1468   49    Male       Married  Travel_Frequently        No
# 1469   34    Male       Married      Travel_Rarely        No
#
# [1470 rows x 5 columns]

# %%
Employee_df['HourlyRate'].corr(Employee_df['MonthlyIncome'])
# Out:
# np.float64(-0.015794304380892937)
