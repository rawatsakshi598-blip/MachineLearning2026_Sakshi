# %%
import pandas as pandas
medical_data=pd.read_csv('C:\Users\acer\Desktop\New folder\MachineLearning2026_Sakshi\dataset')
medical_data

# %%
import pandas as pandas
medical_data=pd.read_csv('C:\Users\acer\Desktop\New folder\MachineLearning2026_Sakshi\dataset')
medical_data

# %%
arning

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Machine Learning
